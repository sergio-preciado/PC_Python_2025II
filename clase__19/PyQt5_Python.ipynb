# %% [markdown]
# <a href="https://colab.research.google.com/github/Warspyt/PC_Python_2025II/blob/main/clase__19/PyQt5_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Curso de Programación de Computadores en Python
# ## Introducción a PyQt5 y Programación Orientada a Eventos
# #### Universidad Nacional de Colombia
#
#
# **Objetivos:**
# - Entender el modelo de programación orientada a eventos (event-driven).
# - Instalar y configurar PyQt5 en un entorno local.
# - Crear ventanas, layouts y agregar widgets (botones, etiquetas, menús, campos de texto).
# - Conectar señales y slots para manejar interacciones.
#
# ---
#
# **Nota importante:** PyQt5 no funciona en Google Colab porque requiere acceso a un servidor gráfico y eventos en el sistema operativo. En este notebook encontrarás instrucciones detalladas y código listo para ejecutar en tu máquina local (Windows/Mac/Linux). Sigue las instrucciones en cada ejercicio para ejecutar los ejemplos localmente.

# %% [markdown]
# ## 🔧 Cómo usar este notebook
#
# - Lee las secciones teóricas aquí en Colab/Jupyter.
# - Para los ejemplos de PyQt5, cada bloque de código contiene un archivo `.py` completo. Copia ese código en un archivo local (por ejemplo `ejemplo_ventana.py`) y ejecútalo desde tu terminal con `python ejemplo_ventana.py`.
# - Asegúrate de tener instalado PyQt5 (`pip install PyQt5`) y un entorno gráfico en tu máquina.
# - Para macOS con Homebrew o Linux, asegúrate de tener instaladas las dependencias de Qt si es necesario.
# - Cada ejercicio incluye un 'Objetivo', 'Instrucciones para ejecución local' y un esqueleto/solución.

# %% [markdown]
# ## 0️⃣ Instalación y comprobación de entorno (local)
#
# ### Requisitos
# - Python 3.7+
# - `pip` instalado
#
# ### Instalación en entorno local
# ```bash
# # Instalar PyQt5 (instala Qt runtime incluido)
# python -m pip install PyQt5
#
# # Opcional: instalar Qt Designer (GUI builder) en Linux/Windows vía instalador oficial o paquetes del SO
# ```
#
# ### Prueba rápida (local)
# Crea un archivo `prueba_pyqt5.py` con el código del primer ejemplo y ejecútalo:
# ```
# python prueba_pyqt5.py
# ```
#
# Si la ventana aparece, la instalación fue exitosa.

# %% [markdown]
# # 1️⃣ Programación orientada a eventos — fundamentos
#
# La programación orientada a eventos (event-driven) se basa en que el flujo del programa está determinado por eventos (clics, entradas de teclado, mensajes de red). En GUI, el framework (Qt) ejecuta un loop de eventos (`QApplication.exec_()`) que despacha señales a los slots (manejadores).
#
# Conceptos clave:
# - **Signal (Señal):** notificación que algo ocurrió (p. ej. `button.clicked`).
# - **Slot:** función que responde a una señal.
# - **Event loop:** bucle que espera y despacha eventos.
#
# En PyQt5 las conexiones se hacen con `widget.signal.connect(slot_function)`.

# %% [markdown]
# ## 2️⃣ Crear una ventana básica
#
# ### Objetivo
# Crear una ventana simple con título y tamaño fijo.
#
# ### Instrucciones para ejecutar localmente
# 1. Copia el código en un archivo llamado `ejemplo_ventana.py`.
# 2. Ejecuta `python ejemplo_ventana.py` en tu terminal local.
#
# ### Código (archivo `ejemplo_ventana.py`)

# %%
# ejemplo_ventana.py
import sys
from PyQt5.QtWidgets import QApplication, QWidget

def main():
    app = QApplication(sys.argv)
    win = QWidget()
    win.setWindowTitle('Ventana básica PyQt5')
    win.setGeometry(100, 100, 400, 250)  # x, y, width, height
    win.show()
    sys.exit(app.exec_())

if __name__ == '__main__':
    main()

# %% [markdown]
# ## 3️⃣ Layouts y organización de widgets
#
# Qt ofrece distintos layouts para organizar widgets automáticamente: `QHBoxLayout`, `QVBoxLayout`, `QGridLayout`, `QFormLayout`.
#
# ### Ejemplo: Ventana con botones en layout vertical
#
# Copia el código en `ejemplo_layout.py` y ejecútalo localmente.

# %%
# ejemplo_layout.py
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QVBoxLayout, QPushButton

def main():
    app = QApplication(sys.argv)
    win = QWidget()
    win.setWindowTitle('Layout Vertical')
    layout = QVBoxLayout()
    btn1 = QPushButton('Botón 1')
    btn2 = QPushButton('Botón 2')
    btn3 = QPushButton('Botón 3')
    layout.addWidget(btn1)
    layout.addWidget(btn2)
    layout.addWidget(btn3)
    win.setLayout(layout)
    win.show()
    sys.exit(app.exec_())

if __name__ == '__main__':
    main()

# %% [markdown]
# ## 4️⃣ Señales y Slots — interacción básica
#
# Conecta la señal `clicked` de un `QPushButton` a una función para que la acción ocurra cuando el usuario haga clic.
#
# ### Ejemplo: botón que cambia el texto de una etiqueta

# %%
# ejemplo_signals.py
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QLabel, QPushButton, QVBoxLayout

def main():
    app = QApplication(sys.argv)
    win = QWidget()
    win.setWindowTitle('Signals y Slots')
    layout = QVBoxLayout()
    label = QLabel('Pulsa el botón...')
    btn = QPushButton('Púlsame')
    def on_click():
        label.setText('¡Botón pulsado!')
    btn.clicked.connect(on_click)
    layout.addWidget(label)
    layout.addWidget(btn)
    win.setLayout(layout)
    win.show()
    sys.exit(app.exec_())

if __name__ == '__main__':
    main()

# %% [markdown]
# ## 5️⃣ Widgets comunes: QLineEdit, QTextEdit, QLabel, QMenuBar
#
# ### Ejemplo: formulario sencillo con entrada de texto y menú

# %%
# ejemplo_widgets.py
import sys
from PyQt5.QtWidgets import (QApplication, QMainWindow, QWidget, QLabel, QLineEdit,
                             QTextEdit, QPushButton, QVBoxLayout, QHBoxLayout, QMenuBar, QAction)

class MainWindow(QMainWindow):
    def __init__(self):
        super().__init__()
        self.setWindowTitle('Widgets y Menú')
        central = QWidget()
        self.setCentralWidget(central)
        layout = QVBoxLayout()
        # Campo de texto
        self.input = QLineEdit()
        self.input.setPlaceholderText('Escribe tu nombre...')
        # Etiqueta
        self.label = QLabel('Hola:')
        # Text area
        self.textarea = QTextEdit()
        # Botón
        btn = QPushButton('Saludar')
        btn.clicked.connect(self.saludar)
        # Menú
        menubar = QMenuBar()
        file_menu = menubar.addMenu('Archivo')
        exit_action = QAction('Salir', self)
        exit_action.triggered.connect(self.close)
        file_menu.addAction(exit_action)
        self.setMenuBar(menubar)
        layout.addWidget(self.input)
        layout.addWidget(btn)
        layout.addWidget(self.label)
        layout.addWidget(self.textarea)
        central.setLayout(layout)

    def saludar(self):
        nombre = self.input.text().strip() or 'invitado'
        self.label.setText(f'Hola: {nombre}')
        self.textarea.append(f'Saludado: {nombre}')

def main():
    app = QApplication(sys.argv)
    win = MainWindow()
    win.resize(500,400)
    win.show()
    sys.exit(app.exec_())

if __name__ == '__main__':
    main()

# %% [markdown]
# ## 6️⃣ Diálogos y cajas de mensaje
#
# Qt ofrece diálogos estándar como `QMessageBox`, `QFileDialog`, `QInputDialog`.
#
# ### Ejemplo: usar QMessageBox y QFileDialog

# %%
# ejemplo_dialogs.py
import sys
from PyQt5.QtWidgets import (QApplication, QWidget, QPushButton, QVBoxLayout,
                             QMessageBox, QFileDialog)

def main():
    app = QApplication(sys.argv)
    win = QWidget()
    win.setWindowTitle('Diálogos')
    layout = QVBoxLayout()
    btn_msg = QPushButton('Mostrar mensaje')
    def show_msg():
        QMessageBox.information(win, 'Info', 'Este es un mensaje de información.')
    btn_msg.clicked.connect(show_msg)
    btn_file = QPushButton('Seleccionar archivo')
    def select_file():
        fname, _ = QFileDialog.getOpenFileName(win, 'Selecciona un archivo', '', 'All Files (*)')
        if fname:
            QMessageBox.information(win, 'Archivo seleccionado', fname)
    btn_file.clicked.connect(select_file)
    layout.addWidget(btn_msg)
    layout.addWidget(btn_file)
    win.setLayout(layout)
    win.show()
    sys.exit(app.exec_())

if __name__ == '__main__':
    main()

# %% [markdown]
# ## 7️⃣ Tips, recomendaciones y buenas prácticas
#
# - Usa `Qt Designer` para diseñar interfaces visualmente y luego conviértelas con `pyuic5` a código Python.
# - Mantén lógica y UI separadas: crea clases para ventanas y módulos para lógica de negocio.
# - Maneja errores en slots con `try/except` para evitar romper el event loop.
# - Usa `QThread` o `concurrent.futures` para tareas de larga duración (no bloquear el event loop).
# - Prueba en diferentes plataformas (Windows, macOS, Linux) porque los estilos nativos difieren.

# %% [markdown]
# ## 8️⃣ Ejercicios prácticos (ejecución local requerida)
#
# Cada ejercicio incluye objetivo, instrucciones de ejecución local, esqueleto y una solución de referencia.

# %% [markdown]
# ### Ejercicio 1 — 'Contador de clics' (corto)
#
# **Objetivo:** Crear una ventana con un botón y un label que muestre cuántas veces se ha pulsado el botón.
#
# **Instrucciones (local):** Crear `contador.py` con el siguiente esqueleto y ejecutar `python contador.py`.

# %%
# contador.py (esqueleto)
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QLabel, QVBoxLayout

def main():
    app = QApplication(sys.argv)
    win = QWidget()
    win.setWindowTitle('Contador de clics')
    layout = QVBoxLayout()
    label = QLabel('Clics: 0')
    btn = QPushButton('Haz clic')
    # TODO: conectar btn.clicked a una función que incremente contador y actualice label
    layout.addWidget(label)
    layout.addWidget(btn)
    win.setLayout(layout)
    win.show()
    sys.exit(app.exec_())

if __name__ == '__main__':
    main()

# %%
# contador.py (solución)
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QPushButton, QLabel, QVBoxLayout

def main():
    app = QApplication(sys.argv)
    win = QWidget()
    win.setWindowTitle('Contador de clics')
    layout = QVBoxLayout()
    label = QLabel('Clics: 0')
    btn = QPushButton('Haz clic')
    contador = {'n': 0}
    def on_click():
        contador['n'] += 1
        label.setText(f'Clics: {contador["n"]}')
    btn.clicked.connect(on_click)
    layout.addWidget(label)
    layout.addWidget(btn)
    win.setLayout(layout)
    win.show()
    sys.exit(app.exec_())

if __name__ == '__main__':
    main()

# %% [markdown]
# ### Ejercicio 2 — 'Formulario con validación' (medio)
#
# **Objetivo:** Crear un formulario con `QLineEdit` para nombre y edad. Validar que la edad sea un entero positivo al pulsar 'Enviar'. Mostrar errores con `QMessageBox`.

# %%
# formulario.py (esqueleto)
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QLineEdit, QLabel, QPushButton, QVBoxLayout, QMessageBox

# TODO: implementar formulario con validación local

# %%
# formulario.py (solución)
import sys
from PyQt5.QtWidgets import QApplication, QWidget, QLineEdit, QLabel, QPushButton, QVBoxLayout, QMessageBox

def main():
    app = QApplication(sys.argv)
    win = QWidget()
    win.setWindowTitle('Formulario')
    layout = QVBoxLayout()
    name_in = QLineEdit(); name_in.setPlaceholderText('Nombre')
    age_in = QLineEdit(); age_in.setPlaceholderText('Edad')
    btn = QPushButton('Enviar')
    def enviar():
        name = name_in.text().strip()
        age = age_in.text().strip()
        if not name:
            QMessageBox.warning(win, 'Error', 'El nombre no puede estar vacío.')
            return
        try:
            age_v = int(age)
            if age_v <= 0:
                raise ValueError
        except:
            QMessageBox.warning(win, 'Error', 'La edad debe ser un entero positivo.')
            return
        QMessageBox.information(win, 'OK', f'Hola {name}, edad {age_v}')
    btn.clicked.connect(enviar)
    layout.addWidget(name_in); layout.addWidget(age_in); layout.addWidget(btn)
    win.setLayout(layout)
    win.show()
    sys.exit(app.exec_())

if __name__ == '__main__':
    main()

# %% [markdown]
# ### Proyecto final — 'Mini editor de notas' (largo)
#
# **Descripción:** Crear una aplicación de notas con:
# - Menú 'Archivo' con 'Nuevo', 'Abrir', 'Guardar'.
# - Área de texto (`QTextEdit`) para editar notas.
# - Guardar y abrir archivos locales usando `QFileDialog`.
# - Manejar guardado automático (cada X minutos) en hilo separado.
#
# **Instrucciones (local):**
# 1. Crear `notas.py` con la clase principal `NotesApp(QMainWindow)`.
# 2. Implementar menús y acciones.
# 3. Usar `QThread` o `QTimer` para guardado automático (no bloquear UI).
# 4. Probar abrir/guardar varios archivos.
#
# Adjunto un esqueleto y una guía de solución (no completa) que puedes extender.

# %%
# notas.py (esqueleto - guía)
import sys
from PyQt5.QtWidgets import QMainWindow, QApplication, QTextEdit, QAction, QFileDialog, QMessageBox
from PyQt5.QtCore import QTimer

class NotesApp(QMainWindow):
    def __init__(self):
        super().__init__()
        self.setWindowTitle('Mini Editor de Notas')
        self.text = QTextEdit()
        self.setCentralWidget(self.text)
        # TODO: crear menús (Archivo: Nuevo, Abrir, Guardar)
        # TODO: implementar funciones: nuevo(), abrir(), guardar()
        # TODO: implementar guardado automático con QTimer o QThread

def main():
    app = QApplication(sys.argv)
    win = NotesApp()
    win.resize(800,600)
    win.show()
    sys.exit(app.exec_())

if __name__ == '__main__':
    main()

# %% [markdown]
# ## 9️⃣ Recursos, lecturas y cierre
#
# - PYQT5 Tutorial: https://www.tutorialspoint.com/pyqt5/index.htm
# - Documentación oficial: https://www.riverbankcomputing.com/software/pyqt/intro
# - Tutoriales: Real Python, ZetCode PyQt5 tutorial
# - Qt Designer: herramienta visual para diseñar GUIs y exportar `.ui` que se pueden convertir a `.py` con `pyuic5`.
# - Recuerda: no bloquees el event loop; usa hilos o timers para tareas largas.
